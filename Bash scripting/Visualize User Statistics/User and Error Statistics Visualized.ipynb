# %% [markdown]
# # User and Error Statistics Visualized
#
# ### Generate:
#
# - The ranking of errors generated by the system: A list of all the error messages logged and how many times each error was found, **sorted by the most common error to the least common error**. This report doesn't take into account the users involved.
#
# - The user usage statistics for the service: A list of all users that have used the system, including how many info messages and how many error messages they've generated. This report is **sorted by username**.
#
# - Visualize them as tables in directory **var/www/html**

# %%
import re
import operator
import csv

error = {}
user = {}
set_users = set()
with open ('syslog.log', 'r') as f:
        lines = list(f)
        for line in lines:
                print("line",line)

                error_type = re.search(r"ticky: ERROR (.*) \(", line)
                user_name = re.search(r" \((.*)\)", line)
                #print("user",user_name.group(1))
                if user_name.group(1) not in set_users:
                        user[user_name.group(1)] = {'usr': user_name.group(1),'ERROR':0, 'INFO':0}
                        set_users.add(user_name.group(1))
                if error_type!=None:
                        #print("error", error_type.group(1))
                        try:
                                error[error_type.group(1)]+=1
                        except:
                                error[error_type.group(1)] =1 

                        user[user_name.group(1)]["ERROR"] += 1
                                
                if error_type==None:
                        #print("info")
                        user[user_name.group(1)]["INFO"] += 1
                                
error = sorted(error.items(), key=operator.itemgetter(1), reverse=True) 
error = dict(error)
print(dict(error))

with open('error_message.csv', 'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames = list(error.keys()))
        writer.writeheader()
        writer.writerow(error)
        
print(user)
set_users = sorted(set_users)

with open('user_statistics.csv', 'w') as csvfile:
        for usr in set_users:
            writer = csv.DictWriter(csvfile, fieldnames = list(user[usr].keys()))
            writer.writeheader()
            writer.writerow(user[usr])
# Out:
# line Jan 31 00:09:39 ubuntu.local ticky: INFO Created ticket [#4217] (mdouglas)
#
# line Jan 31 00:16:25 ubuntu.local ticky: INFO Closed ticket [#1754] (noel)
#
# line Jan 31 00:21:30 ubuntu.local ticky: ERROR The ticket was modified while updating (breee)
#
# line Jan 31 00:44:34 ubuntu.local ticky: ERROR Permission denied while closing ticket (ac)
#
# line Jan 31 01:00:50 ubuntu.local ticky: INFO Commented on ticket [#4709] (blossom)
#
# line Jan 31 01:29:16 ubuntu.local ticky: INFO Commented on ticket [#6518] (rr.robinson)
#
# line Jan 31 01:33:12 ubuntu.local ticky: ERROR Tried to add information to closed ticket (mcintosh)
#
# line Jan 31 01:43:10 ubuntu.local ticky: ERROR Tried to add information to closed ticket (jackowens)
#
# line Jan 31 01:49:29 ubuntu.local ticky: ERROR Tried to add information to closed ticket (mdouglas)
#
# line Jan 31 02:30:04 ubuntu.local ticky: ERROR Timeout while retrieving information (oren)
#
# line Jan 31 02:55:31 ubuntu.local ticky: ERROR Ticket doesn't exist (xlg)
#
# line Jan 31 03:05:35 ubuntu.local ticky: ERROR Timeout while retrieving information (ahmed.miller)
#
# line Jan 31 03:08:55 ubuntu.local ticky: ERROR Ticket doesn't exist (blossom)
#
# line Jan 31 03:39:27 ubuntu.local ticky: ERROR The ticket was modified while updating (bpacheco)
#
# line Jan 31 03:47:24 ubuntu.local ticky: ERROR Ticket doesn't exist (enim.non)
#
# line Jan 31 04:30:04 ubuntu.local ticky: ERROR Permission denied while closing ticket (rr.robinson)
#
# line Jan 31 04:31:49 ubuntu.local ticky: ERROR Tried to add information to closed ticket (oren)
#
# line Jan 31 04:32:49 ubuntu.local ticky: ERROR Timeout while retrieving information (mcintosh)
#
# line Jan 31 04:44:23 ubuntu.local ticky: ERROR Timeout while retrieving information (ahmed.miller)
#
# line Jan 31 04:44:46 ubuntu.local ticky: ERROR Connection to DB failed (jackowens)
#
# line Jan 31 04:49:28 ubuntu.local ticky: ERROR Permission denied while closing ticket (flavia)
#
# line Jan 31 05:12:39 ubuntu.local ticky: ERROR Tried to add information to closed ticket (oren)
#
# line Jan 31 05:18:45 ubuntu.local ticky: ERROR Tried to add information to closed ticket (sri)
#
# line Jan 31 05:23:14 ubuntu.local ticky: INFO Commented on ticket [#1097] (breee)
#
# line Jan 31 05:35:00 ubuntu.local ticky: ERROR Connection to DB failed (nonummy)
#
# line Jan 31 05:45:30 ubuntu.local ticky: INFO Created ticket [#7115] (noel)
#
# line Jan 31 05:51:30 ubuntu.local ticky: ERROR The ticket was modified while updating (flavia)
#
# line Jan 31 05:57:46 ubuntu.local ticky: INFO Commented on ticket [#2253] (nonummy)
#
# line Jan 31 06:12:02 ubuntu.local ticky: ERROR Connection to DB failed (oren)
#
# line Jan 31 06:26:38 ubuntu.local ticky: ERROR Timeout while retrieving information (xlg)
#
# line Jan 31 06:32:26 ubuntu.local ticky: INFO Created ticket [#7298] (ahmed.miller)
#
# line Jan 31 06:36:25 ubuntu.local ticky: ERROR Timeout while retrieving information (flavia)
#
# line Jan 31 06:57:00 ubuntu.local ticky: ERROR Connection to DB failed (jackowens)
#
# line Jan 31 06:59:57 ubuntu.local ticky: INFO Commented on ticket [#7255] (oren)
#
# line Jan 31 07:59:56 ubuntu.local ticky: ERROR Ticket doesn't exist (flavia)
#
# line Jan 31 08:01:40 ubuntu.local ticky: ERROR Tried to add information to closed ticket (jackowens)
#
# line Jan 31 08:03:19 ubuntu.local ticky: INFO Closed ticket [#1712] (britanni)
#
# line Jan 31 08:22:37 ubuntu.local ticky: INFO Created ticket [#2860] (mcintosh)
#
# line Jan 31 08:28:07 ubuntu.local ticky: ERROR Timeout while retrieving information (montanap)
#
# line Jan 31 08:49:15 ubuntu.local ticky: ERROR Permission denied while closing ticket (britanni)
#
# line Jan 31 08:50:50 ubuntu.local ticky: ERROR Permission denied while closing ticket (montanap)
#
# line Jan 31 09:04:27 ubuntu.local ticky: ERROR Tried to add information to closed ticket (noel)
#
# line Jan 31 09:15:41 ubuntu.local ticky: ERROR Timeout while retrieving information (oren)
#
# line Jan 31 09:18:47 ubuntu.local ticky: INFO Commented on ticket [#8385] (mdouglas)
#
# line Jan 31 09:28:18 ubuntu.local ticky: INFO Closed ticket [#2452] (jackowens)
#
# line Jan 31 09:41:16 ubuntu.local ticky: ERROR Connection to DB failed (ac)
#
# line Jan 31 10:11:35 ubuntu.local ticky: ERROR Timeout while retrieving information (blossom)
#
# line Jan 31 10:21:36 ubuntu.local ticky: ERROR Permission denied while closing ticket (montanap)
#
# line Jan 31 11:04:02 ubuntu.local ticky: ERROR Tried to add information to closed ticket (breee)
#
# line Jan 31 11:19:37 ubuntu.local ticky: ERROR Connection to DB failed (sri)
#
# line Jan 31 11:22:06 ubuntu.local ticky: ERROR Timeout while retrieving information (montanap)
#
# line Jan 31 11:31:34 ubuntu.local ticky: ERROR Permission denied while closing ticket (ahmed.miller)
#
# line Jan 31 11:40:25 ubuntu.local ticky: ERROR Connection to DB failed (mai.hendrix)
#
# line Jan 31 11:47:07 ubuntu.local ticky: INFO Commented on ticket [#4562] (ac)
#
# line Jan 31 11:58:33 ubuntu.local ticky: ERROR Tried to add information to closed ticket (ahmed.miller)
#
# line Jan 31 12:00:17 ubuntu.local ticky: INFO Created ticket [#7897] (kirknixon)
#
# line Jan 31 12:02:49 ubuntu.local ticky: ERROR Permission denied while closing ticket (mai.hendrix)
#
# line Jan 31 12:20:23 ubuntu.local ticky: ERROR Connection to DB failed (kirknixon)
#
# line Jan 31 12:20:40 ubuntu.local ticky: ERROR Ticket doesn't exist (flavia)
#
# line Jan 31 12:24:32 ubuntu.local ticky: INFO Created ticket [#5784] (sri)
#
# line Jan 31 12:50:10 ubuntu.local ticky: ERROR Permission denied while closing ticket (blossom)
#
# line Jan 31 12:58:16 ubuntu.local ticky: ERROR Tried to add information to closed ticket (nonummy)
#
# line Jan 31 13:08:10 ubuntu.local ticky: INFO Closed ticket [#8685] (rr.robinson)
#
# line Jan 31 13:48:45 ubuntu.local ticky: ERROR The ticket was modified while updating (breee)
#
# line Jan 31 14:13:00 ubuntu.local ticky: INFO Commented on ticket [#4225] (noel)
#
# line Jan 31 14:38:50 ubuntu.local ticky: ERROR The ticket was modified while updating (enim.non)
#
# line Jan 31 14:41:18 ubuntu.local ticky: ERROR Timeout while retrieving information (xlg)
#
# line Jan 31 14:45:55 ubuntu.local ticky: INFO Closed ticket [#7948] (noel)
#
# line Jan 31 14:50:41 ubuntu.local ticky: INFO Commented on ticket [#8628] (noel)
#
# line Jan 31 14:56:35 ubuntu.local ticky: ERROR Tried to add information to closed ticket (noel)
#
# line Jan 31 15:27:53 ubuntu.local ticky: ERROR Ticket doesn't exist (blossom)
#
# line Jan 31 15:28:15 ubuntu.local ticky: ERROR Permission denied while closing ticket (enim.non)
#
# line Jan 31 15:44:25 ubuntu.local ticky: INFO Closed ticket [#7333] (enim.non)
#
# line Jan 31 16:17:20 ubuntu.local ticky: INFO Commented on ticket [#1653] (noel)
#
# line Jan 31 16:19:40 ubuntu.local ticky: ERROR The ticket was modified while updating (mdouglas)
#
# line Jan 31 16:24:31 ubuntu.local ticky: INFO Created ticket [#5455] (ac)
#
# line Jan 31 16:35:46 ubuntu.local ticky: ERROR Timeout while retrieving information (oren)
#
# line Jan 31 16:53:54 ubuntu.local ticky: INFO Commented on ticket [#3813] (mcintosh)
#
# line Jan 31 16:54:18 ubuntu.local ticky: ERROR Connection to DB failed (bpacheco)
#
# line Jan 31 17:15:47 ubuntu.local ticky: ERROR The ticket was modified while updating (mcintosh)
#
# line Jan 31 17:29:11 ubuntu.local ticky: ERROR Connection to DB failed (oren)
#
# line Jan 31 17:51:52 ubuntu.local ticky: INFO Closed ticket [#8604] (mcintosh)
#
# line Jan 31 18:09:17 ubuntu.local ticky: ERROR The ticket was modified while updating (noel)
#
# line Jan 31 18:43:01 ubuntu.local ticky: ERROR Ticket doesn't exist (nonummy)
#
# line Jan 31 19:00:23 ubuntu.local ticky: ERROR Timeout while retrieving information (blossom)
#
# line Jan 31 19:20:22 ubuntu.local ticky: ERROR Timeout while retrieving information (mai.hendrix)
#
# line Jan 31 19:59:06 ubuntu.local ticky: INFO Created ticket [#6361] (enim.non)
#
# line Jan 31 20:02:41 ubuntu.local ticky: ERROR Timeout while retrieving information (xlg)
#
# line Jan 31 20:21:55 ubuntu.local ticky: INFO Commented on ticket [#7159] (ahmed.miller)
#
# line Jan 31 20:28:26 ubuntu.local ticky: ERROR Connection to DB failed (breee)
#
# line Jan 31 20:35:17 ubuntu.local ticky: INFO Created ticket [#7737] (nonummy)
#
# line Jan 31 20:48:02 ubuntu.local ticky: ERROR Connection to DB failed (mdouglas)
#
# line Jan 31 20:56:58 ubuntu.local ticky: INFO Closed ticket [#4372] (oren)
#
# line Jan 31 21:00:23 ubuntu.local ticky: INFO Commented on ticket [#2389] (sri)
#
# line Jan 31 21:02:06 ubuntu.local ticky: ERROR Connection to DB failed (breee)
#
# line Jan 31 21:20:33 ubuntu.local ticky: INFO Closed ticket [#3297] (kirknixon)
#
# line Jan 31 21:29:24 ubuntu.local ticky: ERROR The ticket was modified while updating (blossom)
#
# line Jan 31 22:58:55 ubuntu.local ticky: INFO Created ticket [#2461] (jackowens)
#
# line Jan 31 23:25:18 ubuntu.local ticky: INFO Closed ticket [#9876] (blossom)
#
# line Jan 31 23:35:40 ubuntu.local ticky: INFO Created ticket [#5896] (mcintosh)
# {'Timeout while retrieving information': 15, 'Connection to DB failed': 13, 'Tried to add information to closed ticket': 12, 'Permission denied while closing ticket': 10, 'The ticket was modified while updating': 9, "Ticket doesn't exist": 7}

# %% [markdown]
# #### To visualize the data in the user_emails.csv file, generate a webpage that'll be served by the webserver running on the machine.
#
# #### The script csv_to_html.py takes in two arguments, the CSV file, and location that would host the HTML page generated. Give write permission to the directory that would host that HTML page:

# %% [markdown]
# ```bash
# !sudo chmod  o+w /var/www/html
# ```

# %% [markdown]
# #### And to visualize the dictionaries run for both error_mesagge and user_statistics

# %%
! python csv_to_html.py error_message.csv var/www/html/error.html
# Out:
# Processing error_message.csv
# var/www/html/error.html already exists. Overwriting...
# Table succesfully written to var/www/html/error.html

# %%
! python csv_to_html.py user_statistics.csv var/www/html/user.html
# Out:
# Processing user_statistics.csv
# var/www/html/user.html already exists. Overwriting...
# Table succesfully written to var/www/html/user.html

# %% [markdown]
# #### and navigate to var/www/html/error.html and var/www/html/user.html
# #### where user statistics is presented
# ![user](img/user.png)
#
# #### as well as error statistics
#
# ![error](img/error.png)

# %% [markdown]
# ### Comments:
#
# - #### use writerow, (not writerows!) - [writerows user the substrings instead of the strings given in list](https://www.reddit.com/r/learnpython/comments/b47rra/error_writing_dictionary_to_csv_file/)
# - #### use [sets](https://www.programiz.com/python-programming/set ) and [nested dictionaries](https://www.programiz.com/python-programming/nested-dictionary)
# - #### easy way to look at the unique elements (and complexity wisely):
#
# `uniqueList = list(set(myList))`

# %% [markdown]
# ### Repetition: sorting

# %% [markdown]
# `sorted, key = operator.itemgetter(0)`

# %%
### sorting wrt to:
import operator

fruit = {"oranges": 3, "apples": 5, "bananas": 7, "pears": 2}
sorted(fruit.items(), key=operator.itemgetter(0))
# Out:
# [('apples', 5), ('bananas', 7), ('oranges', 3), ('pears', 2)]

# %%
sorted(fruit.items())
# Out:
# [('apples', 5), ('bananas', 7), ('oranges', 3), ('pears', 2)]

# %%
sorted(fruit.items(), key=operator.itemgetter(1))
# Out:
# [('pears', 2), ('oranges', 3), ('apples', 5), ('bananas', 7)]

# %%
sorted(fruit.items(), key = operator.itemgetter(1), reverse=True)
# Out:
# [('bananas', 7), ('apples', 5), ('oranges', 3), ('pears', 2)]
